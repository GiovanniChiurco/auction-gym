# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the reduced embedding
ad_reduced_embeddings = pickle.load(open('data/svd/ad_reduced_embeddings.pkl', 'rb'))
sites_embeddings_reduced = pickle.load(open('data/svd/sites_embeddings_reduced.pkl', 'rb'))

# %%
all_sites_emb = np.array(list(sites_embeddings_reduced[70].values())).flatten()

# %%
# Plot distribution of embeddings values
plt.hist(all_sites_emb, bins=50)
plt.show()

# %%
np.where(all_sites_emb > 0.2)[0].shape[0] / all_sites_emb.shape[0]
# Out:
# 0.016782981585806777

# %%
np.where(all_sites_emb < -0.2)[0].shape[0] / all_sites_emb.shape[0]
# Out:
# 0.0010005885815185403
